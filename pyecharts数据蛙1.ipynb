# %% [markdown]
# # Pyecharts 的安装
#
# 创建一个虚拟环境：
# - 创建：conda create --name frog_36 python=3.6
# - 激活：conda activate frog_36
# - 退出：deactivate
# - 删除：conda remove -n frog_36 --all
#
# 安装命令：指定下载镜像
# ⚠️先激活环境：
#
# ```pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pyecharts```
#
# 让虚拟环境自动关联notebook ：安装如下包
#
# ``` conda install nb_conda ```

# %% [markdown]
# ⚠️版本。pyecharts分为v0.5.X和v1两个大版本，v0.5.X和v1间不兼容，v1是一个全新的版本.

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# %% [markdown]
# ** pyecharts 绘图的五个步骤：**
# 1. 创建图形对象
# 2. 添加绘图数据
# 3. 配置系列参数
# 4. 配置全局参数
# 5. 渲染图片

# %%
# l.创建一个柱形图对象
bar = Bar()

# 2.开始添加各个轴的数据
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])

# 3.配置系列参数：对标签、线型等的一些设置

# 4.配置全局参数：对x、y轴、提示框等参数配置
bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))

# 5.渲染
# 生成本地 HTML 文件, 在网页上显示绘图，默认会在当前目录生成 render.html 文件,也可以传入路径参数，如 bar.render("mycharts.html")
# bar.render()

# notebook 渲染
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce8ca5ba2e8f4ddc9575c43ad9e331c8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce8ca5ba2e8f4ddc9575c43ad9e331c8 = echarts.init(
#                     document.getElementById('ce8ca5ba2e8f4ddc9575c43ad9e331c8'), 'white', {renderer: 'canvas'});
#                 var option_ce8ca5ba2e8f4ddc9575c43ad9e331c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ce8ca5ba2e8f4ddc9575c43ad9e331c8.setOption(option_ce8ca5ba2e8f4ddc9575c43ad9e331c8);
#         });
#     </script>

# %%
# 支持链式调用， pycharts一切都是options。

bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e6b223a76db04f54843c831d77fca17f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e6b223a76db04f54843c831d77fca17f = echarts.init(
#                     document.getElementById('e6b223a76db04f54843c831d77fca17f'), 'white', {renderer: 'canvas'});
#                 var option_e6b223a76db04f54843c831d77fca17f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e6b223a76db04f54843c831d77fca17f.setOption(option_e6b223a76db04f54843c831d77fca17f);
#         });
#     </script>

# %%
# 使用主题

# 内置主题类型可查看 pyecharts.globals.ThemeType
from pyecharts.globals import ThemeType
 
bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ed296b89e5b042ea9e9d1eed9d83dd8b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ed296b89e5b042ea9e9d1eed9d83dd8b = echarts.init(
#                     document.getElementById('ed296b89e5b042ea9e9d1eed9d83dd8b'), 'dark', {renderer: 'canvas'});
#                 var option_ed296b89e5b042ea9e9d1eed9d83dd8b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ed296b89e5b042ea9e9d1eed9d83dd8b.setOption(option_ed296b89e5b042ea9e9d1eed9d83dd8b);
#         });
#     </script>

# %% [markdown]
# **内置主题：**
# ![主题](theme.png)

# %% [markdown]
# ### 基本图形的绘制
#
# 1. 条形图
#
#     其实柱形图和条形图的适用场景几乎一样，条形图又称横向柱形图，有时候会直接把条形图规程柱形图的一种，两者较大的一个区别在于：当维度分类较多，而且维度字段名称又较长时，此时应选择条形图，因为条形图能够横向布局，方便展示较长的维度项名称。

# %% [markdown]
# 这里注意：
# add_xaxis的第2个参数，list内的元素必须是int，不能是numpy.int64。

# %%
from pyecharts import options as opts   #配置入口模块
from pyecharts.charts import Bar 

bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)
bar.reversal_axis() #翻转XY轴，将柱状图转换为条形图
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f85e7310618e4588bd75d32398be2178" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f85e7310618e4588bd75d32398be2178 = echarts.init(
#                     document.getElementById('f85e7310618e4588bd75d32398be2178'), 'white', {renderer: 'canvas'});
#                 var option_f85e7310618e4588bd75d32398be2178 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f85e7310618e4588bd75d32398be2178.setOption(option_f85e7310618e4588bd75d32398be2178);
#         });
#     </script>

# %% [markdown]
# 2. 折线图
#
#     当数据X轴为连续数值（如时间）且我们比较注重观察数据变化趋势时，折线图是非常好的选择，并且如果值比较多的时候用折线图也是一个比较好的选择

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

line=Line()
line.add_xaxis(["201{}年/{}季度".format(y,z) 
                for y in range(4) 
                    for z in range(1,5)]) #设置x轴数据
line.add_yaxis(
                "电视机销量", 
                [4.80,4.10,6.00,6.50,5.80,5.20,6.80,7.40,
                 6.00,5.60,7.50,7.80,6.30,5.90,8.00,8.40]
              )#设置y轴数据
line.set_global_opts(
    xaxis_opts=opts.AxisOpts(
        axislabel_opts=opts.LabelOpts(rotate=-40)), #设置x轴标签旋转角度, 避免标签堆积或显示不全
    yaxis_opts=opts.AxisOpts(name="销量（单位/千台）"),#设置y轴名称
    title_opts=opts.TitleOpts(title="折线图"))        #设置图表标题

line.render_notebook() #渲染图表
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9d86128c28d647edafec8997cbc3dcfe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9d86128c28d647edafec8997cbc3dcfe = echarts.init(
#                     document.getElementById('9d86128c28d647edafec8997cbc3dcfe'), 'white', {renderer: 'canvas'});
#                 var option_9d86128c28d647edafec8997cbc3dcfe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7535\u89c6\u673a\u9500\u91cf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010\u5e74/1\u5b63\u5ea6",
#                     4.8
#                 ],
#                 [
#                     "2010\u5e74/2\u5b63\u5ea6",
#                     4.1
#                 ],
#                 [
#                     "2010\u5e74/3\u5b63\u5ea6",
#                     6.0
#                 ],
#                 [
#                     "2010\u5e74/4\u5b63\u5ea6",
#                     6.5
#                 ],
#                 [
#                     "2011\u5e74/1\u5b63\u5ea6",
#                     5.8
#                 ],
#                 [
#                     "2011\u5e74/2\u5b63\u5ea6",
#                     5.2
#                 ],
#                 [
#                     "2011\u5e74/3\u5b63\u5ea6",
#                     6.8
#                 ],
#                 [
#                     "2011\u5e74/4\u5b63\u5ea6",
#                     7.4
#                 ],
#                 [
#                     "2012\u5e74/1\u5b63\u5ea6",
#                     6.0
#                 ],
#                 [
#                     "2012\u5e74/2\u5b63\u5ea6",
#                     5.6
#                 ],
#                 [
#                     "2012\u5e74/3\u5b63\u5ea6",
#                     7.5
#                 ],
#                 [
#                     "2012\u5e74/4\u5b63\u5ea6",
#                     7.8
#                 ],
#                 [
#                     "2013\u5e74/1\u5b63\u5ea6",
#                     6.3
#                 ],
#                 [
#                     "2013\u5e74/2\u5b63\u5ea6",
#                     5.9
#                 ],
#                 [
#                     "2013\u5e74/3\u5b63\u5ea6",
#                     8.0
#                 ],
#                 [
#                     "2013\u5e74/4\u5b63\u5ea6",
#                     8.4
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u89c6\u673a\u9500\u91cf"
#             ],
#             "selected": {
#                 "\u7535\u89c6\u673a\u9500\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -40,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2010\u5e74/1\u5b63\u5ea6",
#                 "2010\u5e74/2\u5b63\u5ea6",
#                 "2010\u5e74/3\u5b63\u5ea6",
#                 "2010\u5e74/4\u5b63\u5ea6",
#                 "2011\u5e74/1\u5b63\u5ea6",
#                 "2011\u5e74/2\u5b63\u5ea6",
#                 "2011\u5e74/3\u5b63\u5ea6",
#                 "2011\u5e74/4\u5b63\u5ea6",
#                 "2012\u5e74/1\u5b63\u5ea6",
#                 "2012\u5e74/2\u5b63\u5ea6",
#                 "2012\u5e74/3\u5b63\u5ea6",
#                 "2012\u5e74/4\u5b63\u5ea6",
#                 "2013\u5e74/1\u5b63\u5ea6",
#                 "2013\u5e74/2\u5b63\u5ea6",
#                 "2013\u5e74/3\u5b63\u5ea6",
#                 "2013\u5e74/4\u5b63\u5ea6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u9500\u91cf\uff08\u5355\u4f4d/\u5343\u53f0\uff09",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9d86128c28d647edafec8997cbc3dcfe.setOption(option_9d86128c28d647edafec8997cbc3dcfe);
#         });
#     </script>

# %% [markdown]
# **3. 饼图、玫瑰图**
#
#     - 部分相较于整体，一个整体被分成几个部分。
#     - 这类情况会用到构成型图表，如五大产品的收件量占比、公司利润的来源构成等。
#     - 对于参与构成研究的数据不超过“9”个时，可以使用饼图来绘制，如果超过了建议使用条形图来展示。

# %%
v1=["啤酒","可乐","雪碧","咖啡","奶茶"]
v2=[30,19,21,12,18]

a = [list(z) for z in zip(v1,v2)]

# %%
a
# Out:
# [['啤酒', 30], ['可乐', 19], ['雪碧', 21], ['咖啡', 12], ['奶茶', 18]]

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie

v1=["啤酒","可乐","雪碧","咖啡","奶茶"]
v2=[30,19,21,12,18]

pie = (
    Pie()
    .add("logo", [list(z) for z in zip(v1,v2)])
    .set_global_opts(title_opts=opts.TitleOpts(title="销售收入占比"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{a}-{b}: {c}%"))#格式化标签输出内容,b代表商品名，c代表比率，a是"logo"
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="44f8fbd793b5405c9fc2b00db0de7392" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_44f8fbd793b5405c9fc2b00db0de7392 = echarts.init(
#                     document.getElementById('44f8fbd793b5405c9fc2b00db0de7392'), 'white', {renderer: 'canvas'});
#                 var option_44f8fbd793b5405c9fc2b00db0de7392 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "logo",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5564\u9152",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5496\u5561",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 18
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{a}-{b}: {c}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5564\u9152",
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u5496\u5561",
#                 "\u5976\u8336"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u9500\u552e\u6536\u5165\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_44f8fbd793b5405c9fc2b00db0de7392.setOption(option_44f8fbd793b5405c9fc2b00db0de7392);
#         });
#     </script>

# %% [markdown]
# **南丁格尔玫瑰图**
#
#     是将柱图转化为更美观饼图形式，是极坐标化的柱图。不同于饼图用角度表现数值或占比，南丁格尔玫瑰图使用扇形的半径表示数据的大小，各扇形的角度则保持一致。
#    [南丁格尔玫瑰图的由来](https://www.sohu.com/a/221082306_416207)

# %%
v1 = ["201{}年/{}季度".format(y,z) for y in range(2) 
                                      for z in range(1,5)]

rose_data = [list(z) for z in zip(v1, [10,20,21,60, 35,23,29,55])]

# %%
rose_data
# Out:
# [['2010年/1季度', 10],
#  ['2010年/2季度', 20],
#  ['2010年/3季度', 21],
#  ['2010年/4季度', 60],
#  ['2011年/1季度', 35],
#  ['2011年/2季度', 23],
#  ['2011年/3季度', 29],
#  ['2011年/4季度', 55]]

# %%
from pyecharts.charts import Pie

pie = (
    Pie()
    .add(
        "",
        rose_data,
        radius=["5%", "75%"],  #从圆心设置半径，第一个参数是空心，第二个是数据。
        rosetype="area",       #玫瑰图有两种类型,area,radius
        label_opts=opts.LabelOpts(is_show=True)
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1794e453d28f433aa6f0ba8960fa9347" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1794e453d28f433aa6f0ba8960fa9347 = echarts.init(
#                     document.getElementById('1794e453d28f433aa6f0ba8960fa9347'), 'white', {renderer: 'canvas'});
#                 var option_1794e453d28f433aa6f0ba8960fa9347 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "2010\u5e74/1\u5b63\u5ea6",
#                     "value": 10
#                 },
#                 {
#                     "name": "2010\u5e74/2\u5b63\u5ea6",
#                     "value": 20
#                 },
#                 {
#                     "name": "2010\u5e74/3\u5b63\u5ea6",
#                     "value": 21
#                 },
#                 {
#                     "name": "2010\u5e74/4\u5b63\u5ea6",
#                     "value": 60
#                 },
#                 {
#                     "name": "2011\u5e74/1\u5b63\u5ea6",
#                     "value": 35
#                 },
#                 {
#                     "name": "2011\u5e74/2\u5b63\u5ea6",
#                     "value": 23
#                 },
#                 {
#                     "name": "2011\u5e74/3\u5b63\u5ea6",
#                     "value": 29
#                 },
#                 {
#                     "name": "2011\u5e74/4\u5b63\u5ea6",
#                     "value": 55
#                 }
#             ],
#             "radius": [
#                 "5%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2010\u5e74/1\u5b63\u5ea6",
#                 "2010\u5e74/2\u5b63\u5ea6",
#                 "2010\u5e74/3\u5b63\u5ea6",
#                 "2010\u5e74/4\u5b63\u5ea6",
#                 "2011\u5e74/1\u5b63\u5ea6",
#                 "2011\u5e74/2\u5b63\u5ea6",
#                 "2011\u5e74/3\u5b63\u5ea6",
#                 "2011\u5e74/4\u5b63\u5ea6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1794e453d28f433aa6f0ba8960fa9347.setOption(option_1794e453d28f433aa6f0ba8960fa9347);
#         });
#     </script>

# %% [markdown]
# rosetype="area",      不理解这个参数
